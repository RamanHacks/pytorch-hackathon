# %%
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/7386756609910767616:predict" &\

# %%
curl -X POST -H "Authorization: Bearer ya29.a0ARrdaM-GR99IiXt6XBgQnmIqwBFd8oMX7w7I9SrvyT4sEHgOrsIK3ENnK0ck-d4b6tBGaRNdnTjAKBIhRPvKXf3cTIAmI3b0tNRo4uhu5zdVPhFQcuXrzwKPip67sRtmUYk7om9sktOAQ-JGtY0pO-jsHEF-6Q" -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://asia-southeast1-aiplatform.googleapis.com/v1/projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296:predict" &\

# %%
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\
curl -X POST -H "Authorization: Bearer "$(gcloud auth application-default print-access-token) -H "Content-Type: application/json; charset=utf-8" -d @sample_b64.json "https://us-central1-aiplatform.googleapis.com/v1/projects/284519662159/locations/us-central1/endpoints/8713629650124800000:predict" &\

# %%
torchserve --stop
sleep 1s
torchserve --start --model-store model-archive/model_store/ --workflow-store model-archive/wf_store/ --ncs
sleep 1s
curl -X POST "localhost:7081/workflows?url=ocr.war"
curl -X POST   -H "Content-Type: application/json; charset=utf-8"   -d @sample_b64.json   localhost:7080/wfpredict/ocr -o output1.json &\
curl -X POST   -H "Content-Type: application/json; charset=utf-8"   -d @sample_b64.json   localhost:7080/wfpredict/ocr -o output2.json &\
curl -X POST   -H "Content-Type: application/json; charset=utf-8"   -d @sample_b64.json   localhost:7080/wfpredict/ocr -o output3.json &\
curl -X POST   -H "Content-Type: application/json; charset=utf-8"   -d @sample_b64.json   localhost:7080/wfpredict/ocr -o output4.json &\

# %%
torchserve --stop
sleep 1s
torchserve --start --model-store model-archive/model_store/ --workflow-store model-archive/wf_store/ --ncs
sleep 1s
curl -X POST "localhost:8081/workflows?url=ocr.war"
curl localhost:8080/wfpredict/ocr -T ../test_images/en.jpg -o output1.json &\
curl localhost:8080/wfpredict/ocr -T ../test_images/ru.png -o output3.json &\
curl localhost:8080/wfpredict/ocr -T ../test_images/en.jpg -o output4.json &\
curl localhost:8080/wfpredict/ocr -T ../test_images/receipt.jpg -o output2.json &\
    
curl localhost:8080/wfpredict/ocr -T ../test_images/en.jpg &\
curl localhost:8080/wfpredict/ocr -T ../test_images/ru.png &\
curl localhost:8080/wfpredict/ocr -T ../test_images/en.jpg &\
curl localhost:8080/wfpredict/ocr -T ../test_images/receipt.jpg &\

# %%
PROJECT_ID = "acquired-vector-330317"
BUCKET_NAME = "gs://ocr-deploy"
REGION = "asia-southeast1"

# %%
hostname = "gcr.io"
tag = "latest"

image_name_serve = "ocr-cpu"
custom_container_image_uri_serve = f"{hostname}/{PROJECT_ID}/{image_name_serve}:{tag}"

# %%
! echo $custom_container_image_uri_serve
! docker build -t $custom_container_image_uri_serve -f Dockerfile .
# Out:
# gcr.io/acquired-vector-330317/ocr-cpu:latest
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/det_handler.py to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/dockerd-ep.sh to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/jit-models to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/jit-models/craft_ts.pt to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/jit-models/crnn_ts.pt to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/logs to tar: archive/tar: missed writing 4791 bytes
# ERRO[0002] Can't add file /home/fsmlp/Desktop/MyRepo/UCR-serve/CPU/logs/access_log.log to tar: archive/tar: missed writing 4791 bytes
# ...

# %%
! docker run -d --name test-ocr4 -p 7080:7080 -p 7081:7081 -p 7082:7082 $custom_container_image_uri_serve
! sleep 15s
# Out:
# 4d038046a846a0bcbe10e5370dfb29f8698439ba6f97e70d69f1dc5ef394e0e2

# %%
! curl http://localhost:7080/ping
! curl -X POST   -H "Content-Type: application/json; charset=utf-8"   -d @sample_b64.json   localhost:7080/wfpredict/ocr
# Out:
# {
#   "status": "Healthy"
# }
# {
#   "predictions": [
#     {
#       "bbox": [
#         [
#           0.03,
#           0.95
#         ],
#         [
#           0.217,
#           0.95
#         ],
#         [
#           0.217,
#           0.9796296296296296
#         ],
#         [
#           0.03,
#           0.9796296296296296
#         ]
#       ],
#       "ocr": [
#         "VectorStock",
#         "0.9144018"
#       ],
#       "key": [
#         "#other",
#         1
#       ]
#     },
#     {
#       "bbox": [
#         [
#           0.644,
#           0.7092592592592593
#         ],
#         [
#           0.72,
#           0.7092592592592593
#         ],
#         [
#           0.72,
#           0.7351851851851852
#         ],
#         [
#           0.644,
#           0.7351851851851852
#         ]
#       ],
#       "ocr": [
#         "84.80",
#         "0.99727744"
#       ],
#       "key": [
#         "#other",
#         1
#       ]
#     },
#     {
# ...

# %%
! docker stop test-ocr4
! docker push $custom_container_image_uri_serve
# Out:
# test-ocr4
# The push refers to repository [gcr.io/acquired-vector-330317/ocr-cpu]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# latest: digest: sha256:ca66d8b2e6075835012c31a2f0eb0ffba9d6c5d82934336b82d9604c9d324b93 size: 4916

# %%
! gcloud container images list --repository $hostname/$PROJECT_ID
# Out:
# NAME
# gcr.io/acquired-vector-330317/ocr-cpu
# gcr.io/acquired-vector-330317/pytorch_predict_finetuned-bert-classifier

# %%
# ! pip install google-cloud-aiplatform
from google.cloud import aiplatform

aiplatform.init(
    project=PROJECT_ID,
    staging_bucket=BUCKET_NAME,
    location=REGION,
)

# %%
model = aiplatform.Model.upload(
    display_name=image_name_serve,
    serving_container_image_uri=custom_container_image_uri_serve,
    serving_container_ports=[7080],
    serving_container_predict_route=f"/wfpredict/ocr",
    serving_container_health_route="/ping",
)
model.wait()

print(model.display_name)
print(model.resource_name)
# Out:
# INFO:google.cloud.aiplatform.models:Creating Model
# INFO:google.cloud.aiplatform.models:Create Model backing LRO: projects/284519662159/locations/asia-southeast1/models/1599938951995457536/operations/523125642263265280
# INFO:google.cloud.aiplatform.models:Model created. Resource name: projects/284519662159/locations/asia-southeast1/models/1599938951995457536
# INFO:google.cloud.aiplatform.models:To use this Model in another session:
# INFO:google.cloud.aiplatform.models:model = aiplatform.Model('projects/284519662159/locations/asia-southeast1/models/1599938951995457536')
# ocr-cpu
# projects/284519662159/locations/asia-southeast1/models/1599938951995457536

# %%
endpoint_display_name = f"{image_name_serve}-endpoint"
endpoint = aiplatform.Endpoint.create(display_name=endpoint_display_name)
# Out:
# INFO:google.cloud.aiplatform.models:Creating Endpoint
# INFO:google.cloud.aiplatform.models:Create Endpoint backing LRO: projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296/operations/2133725459001638912
# INFO:google.cloud.aiplatform.models:Endpoint created. Resource name: projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296
# INFO:google.cloud.aiplatform.models:To use this Endpoint in another session:
# INFO:google.cloud.aiplatform.models:endpoint = aiplatform.Endpoint('projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296')

# %%
traffic_percentage = 100
# machine_type = "n1-standard-4"
machine_type = "n1-standard-8"
min_replica_count = 1
max_replica_count = 3
sync = True

model.deploy(
    endpoint=endpoint,
    machine_type=machine_type,
    traffic_percentage=traffic_percentage,
    sync=sync,
)

model.wait()
# Out:
# INFO:google.cloud.aiplatform.models:Deploying model to Endpoint : projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296
# INFO:google.cloud.aiplatform.models:Deploy Endpoint model backing LRO: projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296/operations/6774121925053513728
# INFO:google.cloud.aiplatform.models:Endpoint model deployed. Resource name: projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296

# %%
import base64

def convert_b64(input_file_name):
    """Open image and convert it to Base64"""
    with open(input_file_name, "rb") as input_file:
        jpeg_bytes = base64.b64encode(input_file.read()).decode("utf-8")
    return jpeg_bytes

# %%
image_file_name = "../test_images/receipt.jpg"
instance = {"data": {"b64": convert_b64(image_file_name)}}
prediction = endpoint.predict(instances=[instance])
print(f"Prediction response: \n\t{prediction}")
# Out:
# Prediction response:
# ...

# %%
google-api-core==2.2.1
google-auth==2.3.2
google-cloud-aiplatform==1.6.1
google-cloud-bigquery==2.29.0
google-cloud-core==2.1.0
google-cloud-storage==1.42.3
google-crc32c==1.3.0
google-resumable-media==2.1.0
googleapis-common-protos==1.53.0

# %%
from typing import Dict

from google.cloud import aiplatform
from google.protobuf import json_format
from google.protobuf.struct_pb2 import Value


def predict_custom_trained_model_sample(
    project: str,
    endpoint_id: str,
    instance_dict: Dict,
    location: str = "us-central1",
    api_endpoint: str = "asia-southeast1-aiplatform.googleapis.com",
):
    # The AI Platform services require regional API endpoints.
    client_options = {"api_endpoint": api_endpoint}
    # Initialize client that will be used to create and send requests.
    # This client only needs to be created once, and can be reused for multiple requests.
    client = aiplatform.gapic.PredictionServiceClient(client_options=client_options)
    # The format of each instance should conform to the deployed model's prediction input schema.
    instance = json_format.ParseDict(instance_dict, Value())
    instances = [instance]
    parameters_dict = {}
    parameters = json_format.ParseDict(parameters_dict, Value())
    endpoint = client.endpoint_path(
        project=project, location=location, endpoint=endpoint_id
    )
    response = client.predict(
        endpoint=endpoint, instances=instances, parameters=parameters
    )
    print("response")
    print(" deployed_model_id:", response.deployed_model_id)
    # The predictions are a google.protobuf.Value representation of the model's predictions.
    predictions = response.predictions
    for prediction in predictions:
        print(" prediction:", dict(prediction))

# %%
from typing import Dict

from google.cloud import aiplatform
from google.protobuf import json_format
from google.protobuf.struct_pb2 import Value

project="284519662159"
endpoint_id="132926557751607296"
location="asia-southeast1"

client_options = {"api_endpoint": "asia-southeast1-aiplatform.googleapis.com"}
client = aiplatform.gapic.PredictionServiceClient(client_options=client_options)
endpoint = client.endpoint_path(
        project=project, location=location, endpoint=endpoint_id
    )

def predict(request):
    """Responds to any HTTP request.
    Args:
        request (flask.Request): HTTP request object.
    Returns:
        The response text or any set of values that can be turned into a
        Response object using
        `make_response <http://flask.pocoo.org/docs/1.0/api/#flask.Flask.make_response>`.
    """
    request_json = request.get_json()
    instance_dict = {"data": {"b64": request_json["data"]}}
    instance = json_format.ParseDict(instance_dict, Value())
    instances = [instance]
    parameters_dict = {}
    parameters = json_format.ParseDict(parameters_dict, Value())

    response = client.predict(
        endpoint=endpoint, instances=instances, parameters=parameters
    )

    return response

# %%
import base64

def convert_b64(input_file_name):
    """Open image and convert it to Base64"""
    with open(input_file_name, "rb") as input_file:
        jpeg_bytes = base64.b64encode(input_file.read()).decode("utf-8")
    return jpeg_bytes

# %%
import glob

# %%
files=glob.glob("/home/fsmlp/Downloads/dataset/testing_data/images/*.png")
for fil in files:
    # image_file_name = "/home/fsmlp/Downloads/test_data/X51005568889.jpg"
    image_file_name = fil
    instance = [{"data": {"b64": convert_b64(image_file_name)}}]
    import json

    with open("/home/fsmlp/Downloads/dataset/testing_data/images/"+image_file_name.split('/')[-1][:-3]+'txt', "w") as f:
        f.write(json.dumps({"instances": instance}))

# %%
projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296
projects/284519662159/locations/asia-southeast1/endpoints/132926557751607296
